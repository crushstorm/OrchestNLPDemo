# %%
import orchest
from common_function import plot_sentiment

# %%
df = orchest.get_inputs()["sentiment1_dataframe"]
color = ['#008972']
plot_sentiment(df,color,"Positive Sentiment")

# %%
## negative sentiment

df = orchest.get_inputs()["sentiment2_dataframe"]
color = ['#9a0026']
plot_sentiment(df,color,"Negative Sentiment")

# %%
import matplotlib.pyplot as plt

# Producing sentiment analysis from snowball method


ax = df.groupby("variation").pos.mean().plot.bar(color = color, figsize = (9, 6))

plt.title('Positive Sentiment', fontsize = 20, weight='bold')

# plt.xlabel('Variation', fontsize = 16, weight='bold')
plt.xticks(rotation='90', fontsize=14, weight='bold')
ax.xaxis.label.set_visible(False)

plt.ylabel('Rating', fontsize=16, weight='bold')
ax.set_ylim([0,0.5])
plt.yticks(fontsize=14)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)


fig = plt.gcf()
plt.show()
plt.draw()
plt.save("image1.jpg")
# Out:
# ---------------------------------------------------------------------------
# OutputNotFoundError                       Traceback (most recent call last)
# /orchest/orchest-sdk/python/orchest/transfer.py in get_inputs(ignore_failure, verbose)
#     974             get_output_method, args, kwargs, metadata = _resolve(
# --> 975                 parent_uuid, consumer=step_uuid
#     976             )
#
# /orchest/orchest-sdk/python/orchest/transfer.py in _resolve(step_uuid, consumer)
#     876         raise error.OutputNotFoundError(
# --> 877             "Output could not be found in memory or on disk."
#     878         )
#
# OutputNotFoundError: Output could not be found in memory or on disk.
#
# During handling of the above exception, another exception occurred:
#
# OutputNotFoundError                       Traceback (most recent call last)
# /usr/local/bin/kernel-launchers/python/scripts/launch_ipykernel.py in <module>
#       3 # Producing sentiment analysis from snowball method
#       4
# ----> 5 df = orchest.get_inputs()["sentiment1_dataframe"]
#       6 color = ['#008972']
#       7 ax = df.groupby("variation").pos.mean().plot.bar(color = color, figsize = (9, 6))
#
# /orchest/orchest-sdk/python/orchest/transfer.py in get_inputs(ignore_failure, verbose)
#     981                 f'("{parent_uuid}") cannot be found. Try rerunning it.'
#     982             )
# --> 983             raise error.OutputNotFoundError(msg)
#     984
#     985         # Maintain the output methods in order, but wait with calling
#
# OutputNotFoundError: Output from incoming step "Stemming - wordnet method" ("a53600f2-27da-4453-9f58-6f1944c53e37") cannot be found. Try rerunning it.

# %%
## negative sentiment

color = ['#9a0026']
ax = df.groupby("variation").neg.mean().plot.bar(color = color, figsize = (9, 6))

plt.title('Negative Sentiment', fontsize = 20, weight='bold')

# plt.xlabel('Variation', fontsize = 16, weight='bold')
plt.xticks(rotation='90', fontsize=14, weight='bold')
ax.xaxis.label.set_visible(False)

plt.ylabel('Rating', fontsize=16, weight='bold')
ax.set_ylim([0,0.5])
plt.yticks(fontsize=14)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)


fig = plt.gcf()
plt.show()
plt.draw()
plt.save("image2.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/bin/kernel-launchers/python/scripts/launch_ipykernel.py in <module>
#      23 plt.show()
#      24 plt.draw()
# ---> 25 plt.save("image2.jpg")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'save'

# %%
# Producing sentiment analysis from wordnet method

df = orchest.get_inputs()["sentiment2_dataframe"]
color = ['#008972']
ax = df.groupby("variation").pos.mean().plot.bar(color = color, figsize = (9, 6))

plt.title('Positive Sentiment', fontsize = 20, weight='bold')

# plt.xlabel('Variation', fontsize = 16, weight='bold')
plt.xticks(rotation='90', fontsize=14, weight='bold')
ax.xaxis.label.set_visible(False)

plt.ylabel('Rating', fontsize=16, weight='bold')
ax.set_ylim([0,0.5])
plt.yticks(fontsize=14)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)


fig = plt.gcf()
plt.show()
plt.draw()

# %%
## negative sentiment

color = ['#9a0026']
ax = df.groupby("variation").neg.mean().plot.bar(color = color, figsize = (9, 6))

plt.title('Negative Sentiment', fontsize = 20, weight='bold')

# plt.xlabel('Variation', fontsize = 16, weight='bold')
plt.xticks(rotation='90', fontsize=14, weight='bold')
ax.xaxis.label.set_visible(False)

plt.ylabel('Rating', fontsize=16, weight='bold')
ax.set_ylim([0,0.5])
plt.yticks(fontsize=14)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)


fig = plt.gcf()
plt.show()
plt.draw()
