# %%
import pandas as pd
import orchest
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from common_function import sentimentScore

# %%
df = orchest.get_inputs()["stop_dataframe"]

# %%
#from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
# Use English stemmer.
#lemmatizer = WordNetLemmatizer()
stemmer = SnowballStemmer("english")
#df['reviews_stemmed'] = df['reviews_without_stop'].apply(lambda y:' '.join([lemmatizer.lemmatize(y) for y in y.split()]))
df['reviews_stemmed'] = df['reviews_without_stop'].apply(lambda y:' '.join([stemmer.stem(y) for y in y.split()]))

# %%
sentiment = sentimentScore(df['reviews_stemmed'])

# %%
sentiment
# Out:
# [{'neg': 0.128, 'neu': 0.494, 'pos': 0.379, 'compound': 0.7269},
#  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.9042},
#  {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.3612},
#  {'neg': 0.055, 'neu': 0.621, 'pos': 0.324, 'compound': 0.9732},
#  {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.9371},
#  {'neg': 0.078, 'neu': 0.651, 'pos': 0.27, 'compound': 0.7096},
#  {'neg': 0.0, 'neu': 0.506, 'pos': 0.494, 'compound': 0.8316},
#  {'neg': 0.0, 'neu': 0.598, 'pos': 0.402, 'compound': 0.8122},
#  {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.8655},
#  {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.608, 'pos': 0.392, 'compound': 0.7003},
#  {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.7906},
#  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.3612},
#  {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.6369},
# ...

# %%
sentiment_df = pd.DataFrame(sentiment)
df.index = sentiment_df.index
#sentiment_df['rating'] = df['rating']
sentiment_add_df = pd.concat([df, sentiment_df], axis=1)
sentiment_add_df.head(100)
# Out:
#                         date  \
# 0   2017-01-13T00:00:00.000Z
# 1   2017-01-13T00:00:00.000Z
# 2   2017-01-13T00:00:00.000Z
# 3   2017-01-13T00:00:00.000Z
# 4   2017-01-12T00:00:00.000Z
# ..                       ...
# 95  2017-01-06T00:00:00.000Z
# 96  2017-01-06T00:00:00.000Z
# 97  2017-01-06T00:00:00.000Z
# 98  2017-01-06T00:00:00.000Z
# 99  2017-01-06T00:00:00.000Z
#
#                                             variation  \
# 0   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# ..                                                ...
# 95  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 96  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 97  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 98  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# ...

# %%
orchest.output(sentiment_add_df, name="sentiment1_dataframe")

# %%
sentiment_add_df['reviews_stemmed']
# Out:
# 0       this product far disappointed. my children lov...
# 1         great beginn experienc person. bought gift love
# 2       inexpens tablet use learn on, step nabi. he th...
# 3       i'v fire hd 8 two week i love it. this tablet ...
# 4       i bought grand daughter come visit. i set user...
#                               ...
# 3456    i purchas gift use anoth home. i also tri simi...
# 3457    love new echo. ask questions...get answers. wa...
# 3458    this good buy recent drop price. despit i love...
# 3459    love it! alexa amazing! it user friend without...
# 3460    my wife want birthday. she love it! speaker co...
# Name: reviews_stemmed, Length: 3461, dtype: object
